# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Rathnayake/House-Price-Prediction/blob/main/data_explore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#the first 4 rows are skipped, which usually contain metadata
dataset = pd.read_csv('/content/API_LKA_DS2_en_csv_v2_100021.csv', skiprows=4)
dataset.head()
# Out:
#   Country Name Country Code  \
# 0    Sri Lanka          LKA
# 1    Sri Lanka          LKA
# 2    Sri Lanka          LKA
# 3    Sri Lanka          LKA
# 4    Sri Lanka          LKA
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Intentional homicides, female (per 100,000 fem...  VC.IHR.PSRC.FE.P5   NaN
# 1           Voice and Accountability: Standard Error         VA.STD.ERR   NaN
# 2        Voice and Accountability: Number of Sources          VA.NO.SRC   NaN
# 3  High-technology exports (% of manufactured exp...  TX.VAL.TECH.MF.ZS   NaN
# 4                    Export value index (2015 = 100)  TX.VAL.MRCH.XD.WD   NaN
#
#    1961  1962  1963  1964  1965  ...       2016        2017        2018  \
# 0   NaN   NaN   NaN   NaN   NaN  ...   1.174153    0.782261    0.922379
# 1   NaN   NaN   NaN   NaN   NaN  ...   0.122546    0.123969    0.126421
# 2   NaN   NaN   NaN   NaN   NaN  ...  13.000000   13.000000   12.000000
# ...
